# %% [markdown]
# # Weeks 1–2 – Dataset Exploration and Python Setup
# ## Main Tasks:
# + Understand the structure and content of the data before any analysis begins

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Making a un
listing_dfs = []

for year in [2024, 2026]:
    for month in range(1, 13):
        fname = f"CRMLSListing{year}{month:02d}.csv"
        try:
            df = pd.read_csv(fname,parse_dates=['CloseDate'])
            df['Year'] = year
            df['Month'] = month
            listing_dfs.append(df)
        except FileNotFoundError:
            # Skip months that don't exist yet
            continue

# If you want one big DataFrame:
all_listings_df = pd.concat(listing_dfs, ignore_index=True)

# %%
all_listings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 451075 entries, 0 to 451074
# Data columns (total 86 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   OriginalListPrice             449300 non-null  float64
#  1   ListingKey                    451075 non-null  int64
#  2   ListAgentEmail                418402 non-null  object
#  3   CloseDate                     106708 non-null  datetime64[ns]
#  4   ClosePrice                    92307 non-null   float64
#  5   ListAgentFirstName            448276 non-null  object
#  6   ListAgentLastName             451040 non-null  object
#  7   Latitude                      344756 non-null  float64
#  8   Longitude                     345261 non-null  float64
#  9   UnparsedAddress               449916 non-null  object
#  10  PropertyType                  451075 non-null  object
#  11  LivingArea                    393411 non-null  float64
# ...

# %%
print("Preview of Concatenated Listing DataFrame")
display(all_listings_df.head())

print("---------/--------")
print("All columns in DataFrame\n")
print(all_listings_df.columns)
print("---------/--------")
print("Description of DataFrame\n")
print(all_listings_df.describe)
# Out:
# Preview of Concatenated Listing DataFrame
#    OriginalListPrice  ListingKey                        ListAgentEmail  \
# 0            90000.0  1075010398                miriamlara03@gmail.com
# 1          1500000.0  1074974457                  janelle@judsonre.com
# 2          1340000.0  1074973329                    haleh360@Gmail.com
# 3          2500000.0  1074954552  Reneechen@yourhomesoldguaranteed.com
# 4          3150000.0  1074936537                      anader@dppre.com
#
#   CloseDate  ClosePrice ListAgentFirstName ListAgentLastName   Latitude  \
# 0       NaT         NaN             Miriam              Lara  34.097939
# 1       NaT         NaN            Janelle            Judson  33.121241
# 2       NaT         NaN              Haleh       Dowlatshahi  34.052207
# 3       NaT         NaN              Renee              Chen  33.496363
# 4       NaT         NaN           Margaret             Nader  34.119345
#
# ...

# %%
prop_type = all_listings_df['PropertyType'].unique()
print(prop_type)
# Out:
# ['ManufacturedInPark' 'CommercialSale' 'Residential' 'ResidentialLease'
#  'Land' 'ResidentialIncome' 'CommercialLease' 'BusinessOpportunity']

# %%
residential_listings_df=all_listings_df[all_listings_df['PropertyType']=='Residential']
residential_listings_df.info()
display(residential_listings_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 285380 entries, 2 to 451072
# Data columns (total 86 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   OriginalListPrice             285005 non-null  float64
#  1   ListingKey                    285380 non-null  int64
#  2   ListAgentEmail                264550 non-null  object
#  3   CloseDate                     67392 non-null   datetime64[ns]
#  4   ClosePrice                    54521 non-null   float64
#  5   ListAgentFirstName            283051 non-null  object
#  6   ListAgentLastName             285365 non-null  object
#  7   Latitude                      207765 non-null  float64
#  8   Longitude                     207765 non-null  float64
#  9   UnparsedAddress               285023 non-null  object
#  10  PropertyType                  285380 non-null  object
#  11  LivingArea                    285092 non-null  float64
# ...
